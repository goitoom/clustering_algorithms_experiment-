# %% [markdown]
# <a href="https://colab.research.google.com/github/goitoom/clustering_algorithms_experiment-/blob/main/Machinelearningcw2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install hdbscan
import hdbscan
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.cluster as cluster
import time
# %matplotlib inline
sns.set_context('poster')
sns.set_color_codes()
plot_kwds = {'alpha' : 0.7, 's' : 15, 'linewidths':3}

# %%
data = np.load('/content/data.npy')

# %%
data.shape
# Out:
# (510, 2)

# %%
data
# Out:
# array([[-0.86472806,  0.53542397],
#        [-0.71685624,  0.26264955],
#        [-0.60927296,  0.69588302],
#        ...,
#        [-0.37392107,  2.27508173],
#        [ 0.06142128,  0.11686344],
#        [-0.05008191, -0.00376259]])

# %%
plt.scatter(data.T[0], data.T[1], c='b', **plot_kwds)
frame = plt.gca()
frame.axes.get_xaxis().set_visible(True)
frame.axes.get_yaxis().set_visible(True)

# %%
#This is the clustering and clusters plotting function
def plot_clusters(data, algorithm, args, kwds):
    start_time = time.time()
    labels = algorithm(*args, **kwds).fit_predict(data)
    end_time = time.time()
    palette = sns.color_palette('Set3', np.unique(labels).max() + 1)
    colors = [palette[x] if x >= 0 else (0.0, 0.0, 0.0) for x in labels]
    plt.scatter(data.T[0], data.T[1], c=colors, **plot_kwds)
    frame = plt.gca()
    frame.axes.get_xaxis().set_visible(True)
    frame.axes.get_yaxis().set_visible(True)
    plt.title('Clusters found by {}'.format(str(algorithm.__name__)), fontsize=18)
    plt.text(0.1, -2.2, 'Clustering took {:.2f} s'.format(end_time - start_time),
  fontsize=14)

# %%
#plot_clusters(data, cluster.MeanShift, (), {'bandwidth': value, 'bin_seeding': value, 'cluster_all': value})

# %%
#plot_clusters(data, cluster.MiniBatchKMeans, (), {'n_clusters': value,'random_state': value, 'batch_size': value, 'init': value,'max_iter': value})

# %%
#plot_clusters(data, cluster.AgglomerativeClustering, (), {'n_clusters':value, 'linkage':'value','metric':'value','compute_full_tree':'value'})

# %%
#plot_clusters(data, hdbscan.HDBSCAN, (), {'min_cluster_size': value, 'min_samples': value, 'alpha': 'value','metric': 'value'})

# %%
plot_clusters(data, cluster.MeanShift, (), {'bandwidth': None, 'bin_seeding': True ,'cluster_all': True})

# %%
plot_clusters(data, cluster.MeanShift, (), {'bandwidth': None, 'bin_seeding': False ,'cluster_all': True })

# %%
plot_clusters(data, cluster.MiniBatchKMeans, (), {'n_clusters':4 ,'random_state':40 , 'batch_size': 60,'init': 'k-means++' , 'max_iter': 100})
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plot_clusters(data, cluster.MiniBatchKMeans, (), {'n_clusters':4 ,'random_state':40 , 'batch_size': 64, 'init': 'k-means++' ,'max_iter': 100})
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plot_clusters(data, cluster.MiniBatchKMeans, (), {'n_clusters':4 ,'random_state':40 , 'batch_size': 60, 'init': 'random' ,'max_iter': 100})
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plot_clusters(data, cluster.MiniBatchKMeans, (), {'n_clusters':4 ,'random_state':40 , 'batch_size': 64, 'init': 'random' ,'max_iter': 100})
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plot_clusters(data, cluster.AgglomerativeClustering, (), {'n_clusters':4, 'linkage':'ward','metric':'euclidean','compute_full_tree':'auto'})

# %%
plot_clusters(data, cluster.AgglomerativeClustering, (), {'n_clusters':4, 'linkage':'complete','metric':'euclidean','compute_full_tree':'auto'})

# %%
plot_clusters(data, cluster.AgglomerativeClustering, (), {'n_clusters':4, 'linkage':'single','metric':'euclidean','compute_full_tree':'auto'})

# %%
plot_clusters(data, hdbscan.HDBSCAN, (), {'min_cluster_size': 5, 'min_samples': 10, 'alpha': 0.5,'metric': 'euclidean'})

# %%
plot_clusters(data, hdbscan.HDBSCAN, (), {'min_cluster_size': 10, 'min_samples': 10, 'alpha': 0.5,'metric': 'euclidean'})

# %%
plot_clusters(data, hdbscan.HDBSCAN, (), {'min_cluster_size': 5, 'min_samples': 10, 'alpha': 1.5,'metric': 'euclidean'})

# %%
plot_clusters(data, hdbscan.HDBSCAN, (), {'min_cluster_size': 10, 'min_samples': 10, 'alpha': 1.5,'metric': 'euclidean'})
